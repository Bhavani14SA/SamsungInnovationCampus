# %%
number=3434
print('the original number is '+str(number))
res=[int(i) for i in str(number)]
print('the list from number is '+str (res))
# Out:
# the original number is 3434
# the list from number is [3, 4, 3, 4]
